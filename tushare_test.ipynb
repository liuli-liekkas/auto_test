# %%
import tushare as ts

# %%
ts.set_token('b54c4caabdbf0e036fc04e0d89fe08011ffb7258b747bfde7ec393d0')

# %%
pro = ts.pro_api()

# %%
ts.get_today_all()
# Out:
# [Getting data:]############################################
#         code   name  changepercent   trade    open    high     low  \
# 0     688981   中芯国际         -0.082   60.95   60.95   61.52   60.23
# 1     688788   科思科技         -4.512  214.37  224.42  227.87  213.39
# 2     688777   中控技术         -4.745   98.97  101.88  104.79   95.26
# 3     688600   皖仪科技         -1.936   19.25   19.71   19.71   19.21
# 4     688599   天合光能         -5.949   20.71   21.81   22.18   20.31
# ...      ...    ...            ...     ...     ...     ...     ...
# 4200  600241  *ST时万         -2.367    3.30    3.35    3.41    3.28
# 4201  600238   ST椰岛         -3.723    5.69    5.91    5.95    5.63
# 4202  600234   ST山水         -1.848    9.03    9.15    9.19    8.78
# 4203  600228   ST昌九         -0.336   11.85   11.89   12.08   11.60
# 4204  600226  *ST瀚叶         -1.053    1.88    1.95    1.96    1.82
#
#       settlement    volume  turnoverratio      amount      per      pb  \
# ...

# %%
df = ts.get_realtime_quotes('002941')
df[['code','name','price','bid','ask','volume','amount','time','b1_v','b1_p','a1_v','a1_p']]
# Out:
#      code  name   price     bid     ask   volume        amount      time b1_v  \
# 0  002941  新疆交建  12.710  12.710  12.710  4531043  57409495.960  14:57:27  129
#
#      b1_p a1_v    a1_p
# 0  12.710  129  12.710
